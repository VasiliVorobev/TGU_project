# %% [markdown]
# ## 2.2.2 Занятие 2 - Ведение проекта git. Практическое задание
#
# Используя Python, создайте небольшое приложение по типу "hello world", намеренно допустите ошибку. Добавьте сокурсника в проект и попросите испраить ошибку в коде - вторая неделя

# %%
# здесь есть ошибка
Print('hello world')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3308391777.py in <cell line: 0>()
# ----> 1 Print('hello world')
#
# NameError: name 'Print' is not defined
